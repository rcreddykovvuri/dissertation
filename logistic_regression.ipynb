# %%
import pandas as pd
import numpy as np

# %%
red_data = pd.read_csv('D://DKIT//dissertation//Dataset_of_Tomato Leaves//datasets//gray_data.csv')

# %%
red_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14531 entries, 0 to 14530
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   image_id     14531 non-null  object
#  1   gray         14531 non-null  object
#  2   gray_single  14531 non-null  object
#  3   disease      14531 non-null  object
# dtypes: object(4)
# memory usage: 454.2+ KB

# %%
red_reg = list(red_data['gray_single'])

# %%
red_reg
# Out:
# ['[147 148 149 ... 118 116 113]',
#  '[166 162 161 ... 135 136 137]',
#  '[128 127 126 ...  53  56  59]',
#  '[116 118 118 ... 169 169 169]',
#  '[173 170 169 ... 117 116 115]',
#  '[ 71  74  78 ... 116 116 116]',
#  '[143 143 142 ... 104 108 113]',
#  '[128 121 123 ... 130 133 137]',
#  '[156 155 152 ... 127 129 128]',
#  '[138 154 160 ... 146 144 141]',
#  '[128 150 131 ... 117 116 115]',
#  '[142 145 148 ... 110 107 104]',
#  '[121 122 122 ... 153 155 158]',
#  '[120 114 122 ... 159 159 159]',
#  '[148 146 144 ...  44  44  44]',
#  '[137 141 141 ... 170 170 170]',
#  '[126 125 123 ... 157 160 163]',
#  '[114 106 102 ... 148 152 156]',
#  '[113 112 116 ... 121 108 123]',
#  '[148 157 166 ... 117 117 117]',
#  '[ 95 100 106 ... 151 151 151]',
#  '[101 103 107 ...  90  89  88]',
#  '[159 158 157 ... 113 110 107]',
#  '[145 145 148 ... 145 145 145]',
#  '[151 150 148 ... 116 116 116]',
#  '[160 162 164 ... 114 120 124]',
#  '[149 150 156 ... 131 131 132]',
# ...

# %%
len(red_reg)
# Out:
# 14531

# %%
type(red_reg)
# Out:
# list

# %%
red = []
for i in red_reg:
    x = []
    x = np.array(i)
    red.append(x)
red
# Out:
# [array('[147 148 149 ... 118 116 113]', dtype='<U29'),
#  array('[166 162 161 ... 135 136 137]', dtype='<U29'),
#  array('[128 127 126 ...  53  56  59]', dtype='<U29'),
#  array('[116 118 118 ... 169 169 169]', dtype='<U29'),
#  array('[173 170 169 ... 117 116 115]', dtype='<U29'),
#  array('[ 71  74  78 ... 116 116 116]', dtype='<U29'),
#  array('[143 143 142 ... 104 108 113]', dtype='<U29'),
#  array('[128 121 123 ... 130 133 137]', dtype='<U29'),
#  array('[156 155 152 ... 127 129 128]', dtype='<U29'),
#  array('[138 154 160 ... 146 144 141]', dtype='<U29'),
#  array('[128 150 131 ... 117 116 115]', dtype='<U29'),
#  array('[142 145 148 ... 110 107 104]', dtype='<U29'),
#  array('[121 122 122 ... 153 155 158]', dtype='<U29'),
#  array('[120 114 122 ... 159 159 159]', dtype='<U29'),
#  array('[148 146 144 ...  44  44  44]', dtype='<U29'),
#  array('[137 141 141 ... 170 170 170]', dtype='<U29'),
#  array('[126 125 123 ... 157 160 163]', dtype='<U29'),
# ...

# %%
column_names = []
for i in range(0,51529):
    x = 'pixel' + str(i)
    column_names.append(x)

# %%
red_reg_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16044/2951529267.py in <module>
# ----> 1 red_reg_data
#
# NameError: name 'red_reg_data' is not defined
